# %%
def solutions():
    # letters = ('s', 'e', 'n', 'd', 'm', 'o', 'r', 'y')
    all_solutions = list()
    for s in range(9, -1, -1):
        for e in range(9, -1, -1):
            for n in range(9, -1, -1):
                for d in range(9, -1, -1):
                    for m in range(9, 0, -1):
                        for o in range(9, -1, -1):
                            for r in range(9, -1, -1):
                                for y in range(9, -1, -1):
                                    if len(set([s, e, n, d, m, o, r, y])) == 8:
                                        send = 1000 * s + 100 * e + 10 * n + d
                                        more = 1000 * m + 100 * o + 10 * r + e
                                        money = 10000 * m + 1000 * o + 100 * n + 10 * e + y

                                        if send + more == money:
                                            all_solutions.append((send, more, money))
    return all_solutions

print(solutions())
# Out:
# [(9567, 1085, 10652)]

# %%
from pprint import pprint
import sys

s1 = 'send'
s2 = 'more'
s3 = 'money'

chars = list(set(s1+s2+s3))
chars.sort()  # So that the order is not random.

def add(a1, a2):
    ## for carry
    l = len(a1)
    result = [None] * l
    carry = 0
    for i in reversed(range(l)):
        if a1[i] is None or a2[i] is None:
            carry = 0
            continue
        result[i] = a1[i] + a2[i] + carry
        if result[i] >= 10:
            result[i] -= 10
            carry = 1
        else:
            carry = 0
    if a1[0] is None or a2[0] is None:
        return [None] + result
    return [carry] + result


def replace(string, mapping):
    return [ mapping.get(string[i], None) for i in range(len(string)) ]


def matches(result1, result2):
    for i, v1 in enumerate(result1):
        v2 = result2[i]
        if v2 != v1 and v2 is not None and v1 is not None and \
            not(i+1 < len(result2) and result2[i+1] is None and v1 == v2 + 1):
                return False
    return True

def value_count(mapping, c):
    m = dict(mapping)
    count = 0
    for i in possible_values(mapping):
        m[c] = i
        if is_valid(m):
            count += 1
    return count

def most_restrained_variable(mapping):
    min_count = 10000
    vals = [ mapping[key] for key in mapping ]
    result = None
    for c in chars:
        if c not in mapping:
            count = value_count(mapping, c)
            if count < min_count:
                min_count = count
                result = c
    return result

def possible_values(mapping):
    vals = [mapping[key] for key in mapping]
    for i in range(10):
        if i not in vals:
            yield i

def least_constrained_ordering(mapping, c):

    def howgood(i):
        m = dict(mapping)
        m[c] = i
        return value_count(m, most_restrained_variable(m))

    ordering = list(possible_values(mapping))
    ordering.sort(key=howgood)
    return reversed(ordering)

def is_valid(mapping):

    # Verify that the mapping does not start with 0.
    if mapping.get(s3[0], None) == 0:
        return False

    # Check that the mapping is arithmetically correct.
    summ = add(replace(s1, mapping), replace(s2, mapping))
    return matches(replace(s3, mapping), summ)


def solver(mapping):
    if not is_valid(mapping):
        return False
    pprint(mapping)

    mapping = dict(mapping)
    if len(mapping) == len(chars):
        pprint(mapping)
        print('done!')
        return True
        
    c = most_restrained_variable(mapping)
    for i in least_constrained_ordering(mapping, c):
        mapping[c] = i
        solver(mapping)
print("\t S\tE\tN\tD\n")
print("+\tM\tO\tR\tE")
print("------------------------------------")
print("M\tO\tN\tE\tY")

if solver({}) == True:
    print(solver({}))
# Out:
# 	 S	E	N	D
#
# +	M	O	R	E
# ------------------------------------
# M	O	N	E	Y
# {}
# {'m': 1}
# {'m': 1, 's': 9}
# {'m': 1, 'o': 0, 's': 9}
# {'d': 8, 'm': 1, 'o': 0, 's': 9}
# {'d': 8, 'e': 6, 'm': 1, 'o': 0, 's': 9}
# {'d': 8, 'e': 6, 'm': 1, 'n': 7, 'o': 0, 's': 9}
# {'d': 8, 'e': 5, 'm': 1, 'o': 0, 's': 9}
# {'d': 8, 'e': 5, 'm': 1, 'n': 6, 'o': 0, 's': 9}
# {'d': 8, 'e': 4, 'm': 1, 'o': 0, 's': 9}
# {'d': 8, 'e': 4, 'm': 1, 'n': 5, 'o': 0, 's': 9}
# {'d': 8, 'e': 7, 'm': 1, 'o': 0, 's': 9}
# {'d': 8, 'e': 3, 'm': 1, 'o': 0, 's': 9}
# {'d': 8, 'e': 2, 'm': 1, 'o': 0, 's': 9}
# {'d': 7, 'm': 1, 'o': 0, 's': 9}
# {'d': 7, 'e': 5, 'm': 1, 'o': 0, 's': 9}
# {'d': 7, 'e': 5, 'm': 1, 'n': 6, 'o': 0, 's': 9}
# {'d': 7, 'e': 5, 'm': 1, 'n': 6, 'o': 0, 'r': 8, 's': 9}
# {'d': 7, 'e': 5, 'm': 1, 'n': 6, 'o': 0, 'r': 8, 's': 9, 'y': 2}
# {'d': 7, 'e': 5, 'm': 1, 'n': 6, 'o': 0, 'r': 8, 's': 9, 'y': 2}
# done!
# {'d': 7, 'e': 8, 'm': 1, 'o': 0, 's': 9}
# {'d': 7, 'e': 6, 'm': 1, 'o': 0, 's': 9}
# {'d': 7, 'e': 4, 'm': 1, 'o': 0, 's': 9}
# {'d': 7, 'e': 3, 'm': 1, 'o': 0, 's': 9}
# {'d': 7, 'e': 2, 'm': 1, 'o': 0, 's': 9}
# {'d': 6, 'm': 1, 'o': 0, 's': 9}
# {'d': 6, 'e': 7, 'm': 1, 'o': 0, 's': 9}
# {'d': 6, 'e': 7, 'm': 1, 'n': 8, 'o': 0, 's': 9}
# {'d': 6, 'e': 2, 'm': 1, 'o': 0, 's': 9}
# {'d': 6, 'e': 2, 'm': 1, 'n': 3, 'o': 0, 's': 9}
# {'d': 6, 'e': 8, 'm': 1, 'o': 0, 's': 9}
# {'d': 6, 'e': 5, 'm': 1, 'o': 0, 's': 9}
# {'d': 6, 'e': 4, 'm': 1, 'o': 0, 's': 9}
# {'d': 6, 'e': 3, 'm': 1, 'o': 0, 's': 9}
# {'d': 5, 'm': 1, 'o': 0, 's': 9}
# {'d': 5, 'e': 7, 'm': 1, 'o': 0, 's': 9}
# {'d': 5, 'e': 7, 'm': 1, 'n': 8, 'o': 0, 's': 9}
# {'d': 5, 'e': 3, 'm': 1, 'o': 0, 's': 9}
# {'d': 5, 'e': 3, 'm': 1, 'n': 4, 'o': 0, 's': 9}
# {'d': 5, 'e': 2, 'm': 1, 'o': 0, 's': 9}
# {'d': 5, 'e': 2, 'm': 1, 'n': 3, 'o': 0, 's': 9}
# {'d': 5, 'e': 8, 'm': 1, 'o': 0, 's': 9}
# {'d': 5, 'e': 6, 'm': 1, 'o': 0, 's': 9}
# {'d': 5, 'e': 4, 'm': 1, 'o': 0, 's': 9}
# {'d': 4, 'm': 1, 'o': 0, 's': 9}
# {'d': 4, 'e': 2, 'm': 1, 'o': 0, 's': 9}
# {'d': 4, 'e': 2, 'm': 1, 'n': 3, 'o': 0, 's': 9}
# {'d': 4, 'e': 8, 'm': 1, 'o': 0, 's': 9}
# {'d': 4, 'e': 7, 'm': 1, 'o': 0, 's': 9}
# {'d': 4, 'e': 6, 'm': 1, 'o': 0, 's': 9}
# {'d': 4, 'e': 5, 'm': 1, 'o': 0, 's': 9}
# {'d': 4, 'e': 3, 'm': 1, 'o': 0, 's': 9}
# {'d': 3, 'm': 1, 'o': 0, 's': 9}
# {'d': 3, 'e': 5, 'm': 1, 'o': 0, 's': 9}
# {'d': 3, 'e': 5, 'm': 1, 'n': 6, 'o': 0, 's': 9}
# {'d': 3, 'e': 4, 'm': 1, 'o': 0, 's': 9}
# {'d': 3, 'e': 4, 'm': 1, 'n': 5, 'o': 0, 's': 9}
# {'d': 3, 'e': 8, 'm': 1, 'o': 0, 's': 9}
# {'d': 3, 'e': 7, 'm': 1, 'o': 0, 's': 9}
# {'d': 3, 'e': 6, 'm': 1, 'o': 0, 's': 9}
# {'d': 3, 'e': 2, 'm': 1, 'o': 0, 's': 9}
# {'d': 2, 'm': 1, 'o': 0, 's': 9}
# {'d': 2, 'e': 6, 'm': 1, 'o': 0, 's': 9}
# {'d': 2, 'e': 6, 'm': 1, 'n': 7, 'o': 0, 's': 9}
# {'d': 2, 'e': 5, 'm': 1, 'o': 0, 's': 9}
# {'d': 2, 'e': 5, 'm': 1, 'n': 6, 'o': 0, 's': 9}
# {'d': 2, 'e': 4, 'm': 1, 'o': 0, 's': 9}
# {'d': 2, 'e': 4, 'm': 1, 'n': 5, 'o': 0, 's': 9}
# {'d': 2, 'e': 3, 'm': 1, 'o': 0, 's': 9}
# {'d': 2, 'e': 3, 'm': 1, 'n': 4, 'o': 0, 's': 9}
# {'d': 2, 'e': 8, 'm': 1, 'o': 0, 's': 9}
# {'d': 2, 'e': 7, 'm': 1, 'o': 0, 's': 9}
# {'m': 9}
# {'m': 8}
# {'m': 7}
# {'m': 6}
# {'m': 5}
# {'m': 4}
# {'m': 3}
# {'m': 2}

# %%
from pprint import pprint
import sys

s1 = 'cross'
s2 = 'roads'
s3 = 'danger'

chars = list(set(s1+s2+s3))
chars.sort()  # So that the order is not random.

def add(a1, a2):
    ## for carry
    l = len(a1)
    result = [None] * l
    carry = 0
    for i in reversed(range(l)):
        if a1[i] is None or a2[i] is None:
            carry = 0
            continue
        result[i] = a1[i] + a2[i] + carry
        if result[i] >= 10:
            result[i] -= 10
            carry = 1
        else:
            carry = 0
    if a1[0] is None or a2[0] is None:
        return [None] + result
    return [carry] + result


def replace(string, mapping):
    return [ mapping.get(string[i], None) for i in range(len(string)) ]


def matches(result1, result2):
    for i, v1 in enumerate(result1):
        v2 = result2[i]
        if v2 != v1 and v2 is not None and v1 is not None and \
            not(i+1 < len(result2) and result2[i+1] is None and v1 == v2 + 1):
                return False
    return True

def value_count(mapping, c):
    m = dict(mapping)
    count = 0
    for i in possible_values(mapping):
        m[c] = i
        if is_valid(m):
            count += 1
    return count

def most_restrained_variable(mapping):
    min_count = 10000
    vals = [ mapping[key] for key in mapping ]
    result = None
    for c in chars:
        if c not in mapping:
            count = value_count(mapping, c)
            if count < min_count:
                min_count = count
                result = c
    return result

def possible_values(mapping):
    vals = [mapping[key] for key in mapping]
    for i in range(10):
        if i not in vals:
            yield i

def least_constrained_ordering(mapping, c):

    def howgood(i):
        m = dict(mapping)
        m[c] = i
        return value_count(m, most_restrained_variable(m))

    ordering = list(possible_values(mapping))
    ordering.sort(key=howgood)
    return reversed(ordering)

def is_valid(mapping):

    # Verify that the mapping does not start with 0.
    if mapping.get(s3[0], None) == 0:
        return False

    # Check that the mapping is arithmetically correct.
    summ = add(replace(s1, mapping), replace(s2, mapping))
    return matches(replace(s3, mapping), summ)


def solver(mapping):
    if not is_valid(mapping):
        return False
    pprint(mapping)

    mapping = dict(mapping)
    if len(mapping) == len(chars):
        pprint(mapping)
        print('done!')
        return True
        
    c = most_restrained_variable(mapping)
    for i in least_constrained_ordering(mapping, c):
        mapping[c] = i
        solver(mapping)
print("\t C\tR\tO\tS\tS\n")
print("+\tR\tO\tA\tD\tS")
print("---------------------------------------------")
print("D\tA\tN\tG\tE\tR")

if solver({}) == True:
    print(solver({}))
# Out:
# 	 C	R	O	S	S
#
# +	R	O	A	D	S
# ---------------------------------------------
# D	A	N	G	E	R
# {}
# {'d': 9}
# {'a': 8, 'd': 9}
# {'a': 8, 'c': 7, 'd': 9}
# {'a': 8, 'c': 6, 'd': 9}
# {'a': 8, 'c': 5, 'd': 9}
# {'a': 8, 'c': 4, 'd': 9}
# {'a': 8, 'c': 3, 'd': 9}
# {'a': 8, 'c': 2, 'd': 9}
# {'a': 8, 'c': 1, 'd': 9}
# {'a': 8, 'c': 0, 'd': 9}
# {'a': 7, 'd': 9}
# {'a': 7, 'c': 8, 'd': 9}
# {'a': 7, 'c': 6, 'd': 9}
# {'a': 7, 'c': 5, 'd': 9}
# {'a': 7, 'c': 4, 'd': 9}
# {'a': 7, 'c': 3, 'd': 9}
# {'a': 7, 'c': 2, 'd': 9}
# {'a': 7, 'c': 1, 'd': 9}
# {'a': 7, 'c': 0, 'd': 9}
# {'a': 6, 'd': 9}
# {'a': 6, 'c': 8, 'd': 9}
# {'a': 6, 'c': 7, 'd': 9}
# {'a': 6, 'c': 5, 'd': 9}
# {'a': 6, 'c': 4, 'd': 9}
# {'a': 6, 'c': 3, 'd': 9}
# {'a': 6, 'c': 2, 'd': 9}
# {'a': 6, 'c': 1, 'd': 9}
# {'a': 6, 'c': 0, 'd': 9}
# {'a': 5, 'd': 9}
# {'a': 5, 'c': 8, 'd': 9}
# {'a': 5, 'c': 7, 'd': 9}
# {'a': 5, 'c': 6, 'd': 9}
# {'a': 5, 'c': 4, 'd': 9}
# {'a': 5, 'c': 3, 'd': 9}
# {'a': 5, 'c': 2, 'd': 9}
# {'a': 5, 'c': 1, 'd': 9}
# {'a': 5, 'c': 0, 'd': 9}
# {'a': 4, 'd': 9}
# {'a': 4, 'c': 8, 'd': 9}
# {'a': 4, 'c': 7, 'd': 9}
# {'a': 7, 'c': 9, 'd': 1, 'r': 8}
# {'a': 7, 'c': 9, 'd': 1, 'o': 0, 'r': 8}
# {'a': 7, 'c': 8, 'd': 1}
# {'a': 7, 'c': 8, 'd': 1, 'r': 9}
# {'a': 7, 'c': 6, 'd': 1}
# {'a': 7, 'c': 5, 'd': 1}
# {'a': 7, 'c': 4, 'd': 1}
# {'a': 7, 'c': 3, 'd': 1}
# {'a': 7, 'c': 2, 'd': 1}
# {'a': 7, 'c': 0, 'd': 1}
# {'a': 6, 'd': 1}
# {'a': 6, 'c': 7, 'd': 1}
# {'a': 6, 'c': 7, 'd': 1, 'r': 8}
# {'a': 6, 'c': 7, 'd': 1, 'r': 8, 's': 4}
# {'a': 6, 'c': 7, 'd': 1, 'e': 5, 'r': 8, 's': 4}
# {'a': 6, 'c': 7, 'd': 1, 'e': 5, 'o': 9, 'r': 8, 's': 4}
# {'a': 6, 'c': 7, 'd': 1, 'e': 5, 'o': 3, 'r': 8, 's': 4}
# {'a': 6, 'c': 7, 'd': 1, 'e': 5, 'o': 2, 'r': 8, 's': 4}
# {'a': 6, 'c': 7, 'd': 1, 'r': 8, 's': 9}
# {'a': 6, 'c': 7, 'd': 1, 'r': 9}
# {'a': 6, 'c': 9, 'd': 1}
# {'a': 6, 'c': 9, 'd': 1, 'r': 7}
# {'a': 6, 'c': 8, 'd': 1}
# {'a': 6, 'c': 8, 'd': 1, 'r': 7}
# {'a': 6, 'c': 5, 'd': 1}
# {'a': 6, 'c': 4, 'd': 1}
# {'a': 6, 'c': 3, 'd': 1}
# {'a': 6, 'c': 2, 'd': 1}
# {'a': 6, 'c': 0, 'd': 1}
# {'a': 5, 'd': 1}
# {'a': 5, 'c': 8, 'd': 1}
# {'a': 5, 'c': 8, 'd': 1, 'r': 6}
# {'a': 5, 'c': 8, 'd': 1, 'r': 6, 's': 3}
# {'a': 5, 'c': 8, 'd': 1, 'e': 4, 'r': 6, 's': 3}
# {'a': 5, 'c': 8, 'd': 1, 'e': 4, 'o': 9, 'r': 6, 's': 3}
# {'a': 5, 'c': 8, 'd': 1, 'e': 4, 'o': 7, 'r': 6, 's': 3}
# {'a': 5, 'c': 8, 'd': 1, 'r': 7}
# {'a': 5, 'c': 6, 'd': 1}
# {'a': 5, 'c': 6, 'd': 1, 'r': 8}
# {'a': 5, 'c': 6, 'd': 1, 'r': 8, 's': 9}
# {'a': 5, 'c': 6, 'd': 1, 'r': 8, 's': 4}
# {'a': 5, 'c': 6, 'd': 1, 'r': 9}
# {'a': 5, 'c': 9, 'd': 1}
# {'a': 5, 'c': 9, 'd': 1, 'r': 6}
# {'a': 5, 'c': 9, 'd': 1, 'r': 6, 's': 8}
# {'a': 5, 'c': 9, 'd': 1, 'e': 0, 'r': 6, 's': 8}
# {'a': 5, 'c': 9, 'd': 1, 'e': 0, 'o': 3, 'r': 6, 's': 8}
# {'a': 5, 'c': 9, 'd': 1, 'e': 0, 'o': 2, 'r': 6, 's': 8}
# {'a': 5, 'c': 9, 'd': 1, 'r': 6, 's': 3}
# {'a': 5, 'c': 9, 'd': 1, 'e': 4, 'r': 6, 's': 3}
# {'a': 3, 'c': 7, 'd': 1, 'r': 6, 's': 8}
# {'a': 3, 'c': 7, 'd': 1, 'e': 0, 'r': 6, 's': 8}
# {'a': 3, 'c': 7, 'd': 1, 'e': 0, 'o': 2, 'r': 6, 's': 8}
# {'a': 3, 'c': 7, 'd': 1, 'r': 5}
# {'a': 3, 'c': 5, 'd': 1}
# {'a': 3, 'c': 5, 'd': 1, 'r': 8}
# {'a': 3, 'c': 5, 'd': 1, 'o': 0, 'r': 8}
# {'a': 3, 'c': 5, 'd': 1, 'r': 7}
# {'a': 3, 'c': 4, 'd': 1}
# {'a': 3, 'c': 4, 'd': 1, 'r': 8}
# {'a': 3, 'c': 4, 'd': 1, 'r': 8, 's': 9}
# {'a': 3, 'c': 4, 'd': 1, 'r': 9}
# {'a': 3, 'c': 9, 'd': 1}
# {'a': 3, 'c': 9, 'd': 1, 'r': 4}
# {'a': 3, 'c': 9, 'd': 1, 'r': 4, 's': 7}
# {'a': 3, 'c': 9, 'd': 1, 'r': 4, 's': 2}
# {'a': 3, 'c': 6, 'd': 1}
# {'a': 3, 'c': 6, 'd': 1, 'r': 7}
# {'a': 3, 'c': 2, 'd': 1}
# {'a': 3, 'c': 0, 'd': 1}
# {'a': 2, 'd': 1}
# {'a': 2, 'c': 8, 'd': 1}
# {'a': 2, 'c': 8, 'd': 1, 'r': 4}
# {'a': 2, 'c': 8, 'd': 1, 'r': 4, 's': 7}
# {'a': 2, 'c': 8, 'd': 1, 'e': 9, 'r': 4, 's': 7}
# {'a': 2, 'c': 8, 'd': 1, 'e': 9, 'o': 5, 'r': 4, 's': 7}
# {'a': 2, 'c': 8, 'd': 1, 'e': 9, 'o': 3, 'r': 4, 's': 7}
# {'a': 2, 'c': 8, 'd': 1, 'e': 9, 'o': 0, 'r': 4, 's': 7}
# {'a': 2, 'c': 8, 'd': 1, 'r': 3}
# {'a': 2, 'c': 7, 'd': 1}
# {'a': 2, 'c': 7, 'd': 1, 'r': 5}
# {'a': 2, 'c': 7, 'd': 1, 'r': 4}
# {'a': 2, 'c': 5, 'd': 1}
# {'a': 2, 'c': 5, 'd': 1, 'r': 6}
# {'a': 2, 'c': 5, 'd': 1, 'r': 6, 's': 8}
# {'a': 2, 'c': 5, 'd': 1, 'e': 0, 'r': 6, 's': 8}
# {'a': 2, 'c': 5, 'd': 1, 'e': 0, 'o': 9, 'r': 6, 's': 8}
# {'a': 2, 'c': 5, 'd': 1, 'e': 0, 'o': 7, 'r': 6, 's': 8}
# {'a': 2, 'c': 5, 'd': 1, 'e': 0, 'o': 4, 'r': 6, 's': 8}
# {'a': 2, 'c': 5, 'd': 1, 'r': 6, 's': 3}
# {'a': 2, 'c': 5, 'd': 1, 'e': 4, 'r': 6, 's': 3}
# {'a': 2, 'c': 5, 'd': 1, 'e': 4, 'o': 9, 'r': 6, 's': 3}
# {'a': 2, 'c': 5, 'd': 1, 'e': 4, 'o': 8, 'r': 6, 's': 3}
# {'a': 2, 'c': 5, 'd': 1, 'e': 4, 'o': 7, 'r': 6, 's': 3}
# {'a': 2, 'c': 5, 'd': 1, 'r': 7}
# {'a': 2, 'c': 4, 'd': 1}
# {'a': 2, 'c': 4, 'd': 1, 'r': 8}
# {'a': 2, 'c': 4, 'd': 1, 'o': 0, 'r': 8}
# {'a': 2, 'c': 4, 'd': 1, 'r': 7}
# {'a': 2, 'c': 3, 'd': 1}
# {'a': 2, 'c': 3, 'd': 1, 'r': 8}
# {'a': 2, 'c': 3, 'd': 1, 'r': 8, 's': 4}
# {'a': 2, 'c': 3, 'd': 1, 'e': 5, 'r': 8, 's': 4}
# {'a': 2, 'c': 3, 'd': 1, 'e': 5, 'o': 9, 'r': 8, 's': 4}
# {'a': 2, 'c': 3, 'd': 1, 'e': 5, 'o': 7, 'r': 8, 's': 4}
# {'a': 2, 'c': 3, 'd': 1, 'e': 5, 'o': 6, 'r': 8, 's': 4}
# {'a': 2, 'c': 3, 'd': 1, 'r': 8, 's': 9}
# {'a': 2, 'c': 3, 'd': 1, 'r': 9}
# {'a': 2, 'c': 9, 'd': 1}
# {'a': 2, 'c': 9, 'd': 1, 'r': 3}
# {'a': 2, 'c': 6, 'd': 1}
# {'a': 2, 'c': 6, 'd': 1, 'r': 5}
# {'a': 2, 'c': 0, 'd': 1}
# {'a': 0, 'd': 1}
# {'a': 0, 'c': 8, 'd': 1}
# {'a': 0, 'c': 8, 'd': 1, 'r': 2}
# {'a': 0, 'c': 8, 'd': 1, 'r': 2, 's': 6}
# {'a': 0, 'c': 7, 'd': 1}
# {'a': 0, 'c': 7, 'd': 1, 'r': 3}
# {'a': 0, 'c': 6, 'd': 1}
# {'a': 0, 'c': 6, 'd': 1, 'r': 4}
# {'a': 0, 'c': 6, 'd': 1, 'r': 4, 's': 7}
# {'a': 0, 'c': 6, 'd': 1, 'e': 9, 'r': 4, 's': 7}
# {'a': 0, 'c': 6, 'd': 1, 'e': 9, 'o': 5, 'r': 4, 's': 7}
# {'a': 0, 'c': 6, 'd': 1, 'e': 9, 'o': 3, 'r': 4, 's': 7}
# {'a': 0, 'c': 6, 'd': 1, 'e': 9, 'o': 2, 'r': 4, 's': 7}
# {'a': 0, 'c': 6, 'd': 1, 'r': 4, 's': 2}
# {'a': 0, 'c': 6, 'd': 1, 'e': 3, 'r': 4, 's': 2}
# {'a': 0, 'c': 6, 'd': 1, 'e': 3, 'o': 5, 'r': 4, 's': 2}
# {'a': 0, 'c': 4, 'd': 1}
# {'a': 0, 'c': 4, 'd': 1, 'r': 6}
# {'a': 0, 'c': 4, 'd': 1, 'o': 2, 'r': 6}
# {'a': 0, 'c': 4, 'd': 1, 'g': 3, 'o': 2, 'r': 6}
# {'a': 0, 'c': 4, 'd': 1, 'g': 3, 'n': 8, 'o': 2, 'r': 6}
# {'a': 0, 'c': 4, 'd': 1, 'o': 3, 'r': 6}
# {'a': 0, 'c': 3, 'd': 1}
# {'a': 0, 'c': 3, 'd': 1, 'r': 7}
# {'a': 0, 'c': 2, 'd': 1}
# {'a': 0, 'c': 2, 'd': 1, 'r': 8}
# {'a': 0, 'c': 9, 'd': 1}
# {'a': 0, 'c': 5, 'd': 1}
